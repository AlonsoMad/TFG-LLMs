# %%
import pandas as pd
import os

# %% [markdown]
# # quora-distilbert-multilingual

# %%
path = '/export/usuarios_ml4ds/ammesa/Data/4_indexed_data/res'
df1 = pd.read_parquet(os.path.join(path, 'preguntas_alonso_v1_results_model_6_tpc_0_thr.parquet'))
df2 = pd.read_parquet(os.path.join(path, 'preguntas_alonso_v1_results_model_6_tpc__dynamic_thr.parquet' ))
df3 = pd.read_parquet(os.path.join(path, 'TB_ENN', 'preguntas_alonso_v1_results_model6tpc_thr_0_combined_to_retrieve_relevant.parquet' ))
df4 = pd.read_parquet(os.path.join(path, 'TB_ENN', 'preguntas_alonso_v1_results_model6tpc_thr__dynamic_combined_to_retrieve_relevant.parquet' ))

# %%
df1
# Out:
#    id     doc_id                                           full_doc  \
# 0   1     EN_0_0  George Washington George Washington (February ...
# 1   2     EN_4_3  Abraham Baldwin Three years later after theolo...
# 2   3   EN_28_14  Andrew Jackson In 1802, he also became major g...
# 3   4   EN_28_14  Andrew Jackson In 1802, he also became major g...
# 4   5  EN_46_123  'Atlantic slave trade The Spanish and Portugue...
# 5   6  EN_118_33  'Charles III of Spain The situation worsened w...
# 6   7  EN_118_33  'Charles III of Spain The situation worsened w...
# 7   8   EN_66_19  'Battle of Jumonville Glen When news of the tw...
# 8   9   EN_66_19  'Battle of Jumonville Glen When news of the tw...
# 9  10   EN_62_25  Battle of Fort Necessity Word of the British m...
#
#                                              passage  \
# 0  George Washington George Washington (February ...
# 1  Abraham Baldwin Three years later after theolo...
# 2  Andrew Jackson In 1802, he also became major g...
# ...

# %%
df2
# Out:
#    id     doc_id                                           full_doc  \
# 0   1     EN_0_0  George Washington George Washington (February ...
# 1   2     EN_4_3  Abraham Baldwin Three years later after theolo...
# 2   3   EN_28_14  Andrew Jackson In 1802, he also became major g...
# 3   4   EN_28_14  Andrew Jackson In 1802, he also became major g...
# 4   5  EN_46_123  'Atlantic slave trade The Spanish and Portugue...
# 5   6  EN_118_33  'Charles III of Spain The situation worsened w...
# 6   7  EN_118_33  'Charles III of Spain The situation worsened w...
# 7   8   EN_66_19  'Battle of Jumonville Glen When news of the tw...
# 8   9   EN_66_19  'Battle of Jumonville Glen When news of the tw...
# 9  10   EN_62_25  Battle of Fort Necessity Word of the British m...
#
#                                              passage  \
# 0  George Washington George Washington (February ...
# 1  Abraham Baldwin Three years later after theolo...
# 2  Andrew Jackson In 1802, he also became major g...
# ...

# %%
df3
# Out:
#       doc_id                                           full_doc  \
# 0     EN_0_0  George Washington George Washington (February ...
# 1     EN_0_0  George Washington George Washington (February ...
# 2     EN_0_0  George Washington George Washington (February ...
# 3     EN_0_0  George Washington George Washington (February ...
# 4     EN_0_0  George Washington George Washington (February ...
# ..       ...                                                ...
# 95  EN_62_25  Battle of Fort Necessity Word of the British m...
# 96  EN_62_25  Battle of Fort Necessity Word of the British m...
# 97  EN_62_25  Battle of Fort Necessity Word of the British m...
# 98  EN_62_25  Battle of Fort Necessity Word of the British m...
# 99  EN_62_25  Battle of Fort Necessity Word of the British m...
#
#                                               passage  \
# 0   George Washington George Washington (February ...
# 1   George Washington George Washington (February ...
# ...

# %%
df4
# Out:
#       doc_id                                           full_doc  \
# 0     EN_0_0  George Washington George Washington (February ...
# 1     EN_0_0  George Washington George Washington (February ...
# 2     EN_0_0  George Washington George Washington (February ...
# 3     EN_0_0  George Washington George Washington (February ...
# 4     EN_0_0  George Washington George Washington (February ...
# ..       ...                                                ...
# 95  EN_62_25  Battle of Fort Necessity Word of the British m...
# 96  EN_62_25  Battle of Fort Necessity Word of the British m...
# 97  EN_62_25  Battle of Fort Necessity Word of the British m...
# 98  EN_62_25  Battle of Fort Necessity Word of the British m...
# 99  EN_62_25  Battle of Fort Necessity Word of the British m...
#
#                                               passage  \
# 0   George Washington George Washington (February ...
# 1   George Washington George Washington (February ...
# ...

# %% [markdown]
# # LaBSE

# %%
path = '/export/usuarios_ml4ds/ammesa/Data/4_indexed_data/res'
df1 = pd.read_parquet(os.path.join(path, 'preguntas_alonso_v1_results_model_6_tpc_0_thr.parquet'))
df2 = pd.read_parquet(os.path.join(path, 'preguntas_alonso_v1_results_model_6_tpc__dynamic_thr.parquet' ))
df3 = pd.read_parquet(os.path.join(path, 'TB_ENN', 'preguntas_alonso_v1_results_model6tpc_thr_0_combined_to_retrieve_relevant.parquet' ))
df4 = pd.read_parquet(os.path.join(path, 'TB_ENN', 'preguntas_alonso_v1_results_model6tpc_thr__dynamic_combined_to_retrieve_relevant.parquet' ))

# %%
df1
# Out:
#    id     doc_id                                           full_doc  \
# 0   1     EN_0_0  George Washington George Washington (February ...
# 1   2     EN_4_3  Abraham Baldwin Three years later after theolo...
# 2   3   EN_28_14  Andrew Jackson In 1802, he also became major g...
# 3   4   EN_28_14  Andrew Jackson In 1802, he also became major g...
# 4   5  EN_46_123  'Atlantic slave trade The Spanish and Portugue...
# 5   6  EN_118_33  'Charles III of Spain The situation worsened w...
# 6   7  EN_118_33  'Charles III of Spain The situation worsened w...
# 7   8   EN_66_19  'Battle of Jumonville Glen When news of the tw...
