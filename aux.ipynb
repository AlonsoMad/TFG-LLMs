# %%
import os
import pandas as pd

# %%
dataframe = pd.read_parquet('/export/usuarios_ml4ds/ammesa/Data/0_input_data/dataset_2025-02-20.parquet.gzip')
dataframe[dataframe['lang'] == 'en']['text'][0][len(dataframe[dataframe['lang'] == 'en']['text'][0])-250:len(dataframe[dataframe['lang'] == 'en']['text'][0])]
# Out:
# 'Middleton, and Colin Bonwick (June 24, 2004)\nGreat Lives: George Washington, BBC Radio 4 discussion with Matthew Parris, Michael Rose, and Frank Grizzard (October 21, 2016)\nScholarly coverage of Washington at the Miller Center, University of Virginia'

# %%
df_seg = pd.read_parquet('/export/usuarios_ml4ds/ammesa/Data/1_segmented_data/en_2025-02-20_segmented_dataset.parquet.gzip')
df_seg
# Out:
#                                             title  \
# 0                               George Washington
# 1                               George Washington
# 2                               George Washington
# 3                               George Washington
# 4                               George Washington
# ...                                           ...
# 63010  Historical background of the New Testament
# 63011  Historical background of the New Testament
# 63012  Historical background of the New Testament
# 63013  Historical background of the New Testament
# 63014  Historical background of the New Testament
#
#                                                  summary  \
# 0      George Washington (February 22 1732 [O.S. Febr...
# 1      George Washington (February 22 1732 [O.S. Febr...
# 2      George Washington (February 22 1732 [O.S. Febr...
# 3      George Washington (February 22 1732 [O.S. Febr...
# 4      George Washington (February 22 1732 [O.S. Febr...
# ...                                                  ...
# 63010  Most scholars who study the historical Jesus a...
# 63011  Most scholars who study the historical Jesus a...
# 63012  Most scholars who study the historical Jesus a...
# 63013  Most scholars who study the historical Jesus a...
# 63014  Most scholars who study the historical Jesus a...
#
#                                                     text lang  \
# 0      George Washington (February 22 1732 [O.S. Febr...   en
# 1      Born in the Colony of Virginia, Washington bec...   en
# 2      Washington was elected president unanimously b...   en
# 3      Washington's image is an icon of American cult...   en
# 4      George Washington was born on February 22, 173...   en
# ...                                                  ...  ...
# 63010  Crossan, John Dominic (1991). The Historical J...   en
# 63011  Ehrman, Bart (2003). The New Testament: A Hist...   en
# 63012  Fredriksen, Paula Jesus of Nazareth, King of t...   en
# 63013  Neusner, Jacob. Judaism When Christianity Bega...   en
# 63014  Orlinsky, H. M. ( 1971). "The Seer-Priest" in ...   en
#
#                                                      url     id  equivalence  \
# 0        https://en.wikipedia.org/wiki/George_Washington      0            1
# 1        https://en.wikipedia.org/wiki/George_Washington      1            1
# 2        https://en.wikipedia.org/wiki/George_Washington      2            1
# 3        https://en.wikipedia.org/wiki/George_Washington      3            1
# 4        https://en.wikipedia.org/wiki/George_Washington      4            1
# ...                                                  ...    ...          ...
# 63010  https://en.wikipedia.org/wiki/Historical_backg...  63010            1
# 63011  https://en.wikipedia.org/wiki/Historical_backg...  63011            1
# 63012  https://en.wikipedia.org/wiki/Historical_backg...  63012            1
# 63013  https://en.wikipedia.org/wiki/Historical_backg...  63013            1
# 63014  https://en.wikipedia.org/wiki/Historical_backg...  63014            1
#
#       id_preproc
# 0         EN_0_0
# 1         EN_0_1
# 2         EN_0_2
# 3         EN_0_3
# 4         EN_0_4
# ...          ...
# 63010  EN_999_61
# 63011  EN_999_62
# 63012  EN_999_63
# 63013  EN_999_64
# 63014  EN_999_65
#
# [63015 rows x 8 columns]

# %%
df_lem = pd.read_parquet('/export/usuarios_ml4ds/ammesa/Data/2_lemmatized_data/en')
df_lem
# Out:
#        id_preproc                                           raw_text  \
# 0          EN_0_0  George Washington George Washington (February ...
# 1          EN_0_1  George Washington Born in the Colony of Virgin...
# 2          EN_0_2  George Washington Washington was elected presi...
# 3          EN_0_3  George Washington Washington's image is an ico...
# 4          EN_0_4  George Washington George Washington was born o...
# ...           ...                                                ...
# 93973  ES_1999_48  Antecedentes históricos del Nuevo Testamento C...
# 93974  ES_1999_49  Antecedentes históricos del Nuevo Testamento E...
# 93975  ES_1999_50  Antecedentes históricos del Nuevo Testamento F...
# 93976  ES_1999_51  Antecedentes históricos del Nuevo Testamento N...
# 93977  ES_1999_52  Antecedentes históricos del Nuevo Testamento O...
#
#                                                   lemmas
# 0      george_washington george_washington february f...
# 1      george_washington bear colony virginia washing...
# 2      george_washington washington elect president e...
# 3      george_washington washington image_icon americ...
# 4      george_washington george_washington bear febru...
# ...                                                  ...
# 93973  antecedentes_históricos del_nuevo testamento c...
# 93974  antecedentes_históricos del_nuevo testamento e...
# 93975  antecedentes_históricos del_nuevo testamento f...
# 93976  antecedentes_históricos del_nuevo testamento n...
# 93977  antecedentes_históricos del_nuevo testamento o...
#
# [64922 rows x 3 columns]

# %%
df_filtered = df_lem[df_lem['id_preproc'].str.startswith('ES_')]
print(df_filtered.shape, df_lem.shape)
# Out:
# (2231, 3) (64922, 3)

# %%
df_seg_es = pd.read_parquet('/export/usuarios_ml4ds/ammesa/Data/1_segmented_data/es_2025-02-20_segmented_dataset.parquet.gzip')
df_seg_es
# Out:
#                                               title  \
# 63015                             George Washington
# 63016                             George Washington
# 63017                             George Washington
# 63018                             George Washington
# 63019                             George Washington
# ...                                             ...
# 93973  Antecedentes históricos del Nuevo Testamento
# 93974  Antecedentes históricos del Nuevo Testamento
# 93975  Antecedentes históricos del Nuevo Testamento
# 93976  Antecedentes históricos del Nuevo Testamento
# 93977  Antecedentes históricos del Nuevo Testamento
#
#                                                  summary  \
# 63015  George Washington (Westmoreland, Virginia, Amé...
# 63016  George Washington (Westmoreland, Virginia, Amé...
# 63017  George Washington (Westmoreland, Virginia, Amé...
# 63018  George Washington (Westmoreland, Virginia, Amé...
# 63019  George Washington (Westmoreland, Virginia, Amé...
# ...                                                  ...
# 93973  La mayoría de los eruditos que estudiaron al J...
# 93974  La mayoría de los eruditos que estudiaron al J...
# 93975  La mayoría de los eruditos que estudiaron al J...
# 93976  La mayoría de los eruditos que estudiaron al J...
# 93977  La mayoría de los eruditos que estudiaron al J...
#
#                                                     text lang  \
# 63015  George Washington (Westmoreland, Virginia, Amé...   es
# 63016  Washington empezó a ganar condecoraciones arma...   es
# 63017  El Congreso Continental designó a Washington c...   es
# 63018  En 1787, presidió la Convención de Filadelfia ...   es
# 63019  Antes de la finalización de su período de gobi...   es
# ...                                                  ...  ...
# 93973  Crossan, John Dominic (1991). The Historical J...   es
# 93974  Ehrman, Bart (2003). The New Testament: A Hist...   es
# 93975  Fredriksen, Paula Jesus of Nazareth, King of t...   es
# 93976  Neusner, Jacob (2002). Judaism When Christiani...   es
# 93977  Orlinsky, H. M. (1971). «The Seer-Priest» en W...   es
#
#                                                      url     id  equivalence  \
# 63015    https://en.wikipedia.org/wiki/George_Washington  63015            1
# 63016    https://en.wikipedia.org/wiki/George_Washington  63016            1
# 63017    https://en.wikipedia.org/wiki/George_Washington  63017            1
# 63018    https://en.wikipedia.org/wiki/George_Washington  63018            1
# 63019    https://en.wikipedia.org/wiki/George_Washington  63019            1
# ...                                                  ...    ...          ...
# 93973  https://en.wikipedia.org/wiki/Historical_backg...  93973            1
# 93974  https://en.wikipedia.org/wiki/Historical_backg...  93974            1
# 93975  https://en.wikipedia.org/wiki/Historical_backg...  93975            1
# 93976  https://en.wikipedia.org/wiki/Historical_backg...  93976            1
# 93977  https://en.wikipedia.org/wiki/Historical_backg...  93977            1
#
#        id_preproc
# 63015   ES_1000_0
# 63016   ES_1000_1
# 63017   ES_1000_2
# 63018   ES_1000_3
# 63019   ES_1000_4
# ...           ...
# 93973  ES_1999_48
# 93974  ES_1999_49
# 93975  ES_1999_50
# 93976  ES_1999_51
# 93977  ES_1999_52
#
# [30963 rows x 8 columns]

# %%
df_lem_es = pd.read_parquet('/export/usuarios_ml4ds/ammesa/Data/2_lemmatized_data/es')
df_lem_es
# Out:
#        id_preproc                                           raw_text  \
# 4219     EN_59_17  Battle of Cape St. Vincent (1780) Duro, Cesáre...
# 4221     EN_59_19  Battle of Cape St. Vincent (1780) Lafuente, Mo...
# 4225     EN_59_23  Battle of Cape St. Vincent (1780) de Ulloa, An...
# 4227     EN_59_25  Battle of Cape St. Vincent (1780) de Castro, A...
# 17168  EN_269_100  Great Siege of Gibraltar Montero, Francisco Ma...
# ...           ...                                                ...
# 93963  ES_1999_38  Antecedentes históricos del Nuevo Testamento D...
# 93964  ES_1999_39  Antecedentes históricos del Nuevo Testamento E...
# 93965  ES_1999_40  Antecedentes históricos del Nuevo Testamento E...
# 93966  ES_1999_41  Antecedentes históricos del Nuevo Testamento D...
# 93967  ES_1999_42  Antecedentes históricos del Nuevo Testamento E...
#
#                                                   lemmas
# 4219   battle_cape vincent duro cesáreo fernández arm...
# 4221   battle_cape vincent lafuente modesto historia ...
# 4225   battle_cape vincent ulloa antonio_pérez mallaí...
# 4227   battle_cape vincent castro adolfo historia cád...
# 17168  great_siege gibraltar montero francisco maria ...
# ...                                                  ...
# 93963  antecedentes_históricos nuevo_testamento despu...
# 93964  antecedentes_históricos nuevo_testamento en em...
# 93965  antecedentes_históricos nuevo_testamento esta ...
# 93966  antecedentes_históricos nuevo_testamento despu...
# 93967  antecedentes_históricos nuevo_testamento el nu...
#
# [28413 rows x 3 columns]

# %%
df_filtered2 = df_lem_es[df_lem_es['id_preproc'].str.startswith('EN_')]
print(df_filtered2.shape, df_lem_es.shape)
# Out:
# (17, 3) (28413, 3)

# %%
from transformers import pipeline
class Translator():
    '''
    Initializes the Hugging Face model and defines as a function
    the pipeline to translate the segmented text afterwards.

    Once translated it recombines the datasets into a suitable format
    ---------------------
    Parameters:
      Takes no parameters
    '''
    def __init__(self,
                 en_df: pd.DataFrame,
                 es_df: pd.DataFrame
                 ):

      self.model_es_en = pipeline("translation", model="Helsinki-NLP/opus-mt-es-en")
      self.model_en_es = pipeline("translation", model='Helsinki-NLP/opus-mt-en-es')

      self.en_df = en_df
      self.es_df = es_df 

      self.split_es_df = None
      self.split_en_df = None

      self.trans_text_es = None
      self.trans_text_en = None

      self.translated_df_es = None
      self.translated_df_en = None
      return

    def split(self, dataframe: pd.DataFrame, language: str) -> None:
      '''
      Takes an input dataset and splits its raw_text column into phrases separated by
      the dot (.)
      ----------------
      Parameters:
        dataframe: A Pandas dataframe that has been previously segmented into paragraphs. 
      '''
      #I append to lists not to pd.DataFrames
      data = []

      for i, row in dataframe.iterrows():
         
          split_text = row['text'].split(". ")

          filtered_text = filter(lambda x: x!='', split_text)

          phrases = list(filtered_text)

          for _, p in enumerate(phrases):
             
             new_row = [
              row["title"], row["summary"], p, row["lang"], row["url"],
              None, #For the dynamic ID
              row["equivalence"], row["id_preproc"] + "_" + str(_)
             ]

             data.append(new_row)
             
      if language == 'en':

        en_df = pd.DataFrame(data, columns=["title", "summary", "text", "lang", "url", "index", "equivalence", "id_preproc"])
        en_df["index"] = range(len(en_df))
        self.split_en_df = en_df          

      elif language == 'es':

        es_df = pd.DataFrame(data, columns=["title", "summary", "text", "lang", "url", "index", "equivalence", "id_preproc"])
        es_df["index"] = range(len(es_df))
        self.split_es_df = es_df

      else:
         raise(Exception(f'The language: {language} is not supported!'))

      return

    def translate(self) -> None:
       '''
       Translates the dataframes to the other respective language
       using hugginface OPUS model
       '''       
       self.split(self.en_df, 'en')
       self.split(self.es_df, 'es')

       self.trans_text_en = self.split_es_df['text'].map(lambda x: self.model_es_en(x))
        
       self.trans_text_es = self.split_en_df['text'].map(lambda x: self.model_en_es(x))

      #Changes format to strings
       self.trans_text_en = self.trans_text_en.explode().apply(lambda x: x["translation_text"] if isinstance(x, dict) else None)

       self.trans_text_es = self.trans_text_es.explode().apply(lambda x: x["translation_text"] if isinstance(x, dict) else None)
         
       self.assemble_dataframes()
       return
    
    def assemble_dataframes(self) -> None:
       '''
       Prepares the final datasets to be saved by the segmenter, 
       substitutes the new translated column, in the df, groups by 
       paragraph and concatenates to the original datasets
       '''
       #First update the split datasets with the translated columns
       self.split_en_df['text'] = self.trans_text_es 
       self.split_es_df['text'] = self.trans_text_en 

       #Now I concatenate from phrases to paragraphs

       self.split_es_df["aux_id"] = self.split_es_df["id_preproc"].str.rsplit("_", n=1).str[0]
       self.split_en_df["aux_id"] = self.split_en_df["id_preproc"].str.rsplit("_", n=1).str[0]
       
       
       grouped_es = (self.split_es_df
                     .groupby("aux_id")["text"]
                     .agg(lambda x: ' '.join(x.astype(str).str.strip()))
                     .reset_index()
                     .rename(columns={"text": "assembled_text"}))
       grouped_en = (self.split_en_df
                     .groupby("aux_id")["text"]
                     .agg(lambda x: ' '.join(x.astype(str).str.strip()))
                     .reset_index()
                     .rename(columns={"text": "assembled_text"}))
                       
       #Erase and ename columns
       merged_es_df = (self.split_es_df
                      .merge(grouped_es, on="aux_id", how="outer")
                      .drop(columns=['text', 'id_preproc'])
                      .rename(columns={'aux_id': 'id_preproc', 
                                      'assembled_text': 'text'})
                      .drop_duplicates(subset=['id_preproc'])
                      .assign(id_preproc=lambda x: 'T_' + x['id_preproc'])
                      .assign(lang=lambda x: 'en')
                      .reset_index(drop=True))
        
       merged_en_df = (self.split_en_df
                      .merge(grouped_en, on="aux_id", how="outer")
                      .drop(columns=['text', 'id_preproc'])
                      .rename(columns={'aux_id': 'id_preproc', 
                                      'assembled_text': 'text'})
                      .drop_duplicates(subset=['id_preproc'])
                      .assign(id_preproc=lambda x: 'T_' + x['id_preproc'])
                      .assign(lang=lambda x: 'es')
                      .reset_index(drop=True))
       
       #Now concatenate the translated to en dataset with the original en dataset
       self.translated_df_en = pd.concat([self.en_df, merged_es_df], ignore_index=True)
       self.translated_df_es = pd.concat([self.es_df, merged_en_df], ignore_index=True)
       

       return 


       
    def save(self) -> None:
       pass
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/utils/import_utils.py:1002, in _LazyModule._get_module(self, module_name)
#    1001 try:
# -> 1002     return importlib.import_module("." + module_name, self.__name__)
#    1003 except Exception as e:
#
# File /usr/local/anaconda312/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/pipelines/__init__.py:31
#      30 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 31 from ..models.auto.configuration_auto import AutoConfig
#      32 from ..models.auto.feature_extraction_auto import FEATURE_EXTRACTOR_MAPPING, AutoFeatureExtractor
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/models/__init__.py:19
#       1 # flake8: noqa
#       2 # There's no way to ignore "F401 '...' imported but unused" warnings in this
#       3 # module, but to preserve other warnings. So, don't check this module at all.
#    (...)
#      16 # See the License for the specific language governing permissions and
#      17 # limitations under the License.
# ---> 19 from . import (
#      20     albert,
#      21     auto,
#      22     bart,
#      23     barthez,
#      24     bartpho,
#      25     beit,
#      26     bert,
#      27     bert_generation,
#      28     bert_japanese,
#      29     bertweet,
#      30     big_bird,
#      31     bigbird_pegasus,
#      32     blenderbot,
#      33     blenderbot_small,
#      34     bloom,
#      35     bort,
#      36     byt5,
#      37     camembert,
#      38     canine,
#      39     clip,
#      40     codegen,
#      41     convbert,
#      42     convnext,
#      43     cpm,
#      44     ctrl,
#      45     cvt,
#      46     data2vec,
#      47     deberta,
#      48     deberta_v2,
#      49     decision_transformer,
#      50     deit,
#      51     detr,
#      52     dialogpt,
#      53     distilbert,
#      54     dit,
#      55     dpr,
#      56     dpt,
#      57     electra,
#      58     encoder_decoder,
#      59     flaubert,
#      60     flava,
#      61     fnet,
#      62     fsmt,
#      63     funnel,
#      64     glpn,
#      65     gpt2,
#      66     gpt_neo,
#      67     gpt_neox,
#      68     gptj,
#      69     groupvit,
#      70     herbert,
#      71     hubert,
#      72     ibert,
#      73     imagegpt,
#      74     layoutlm,
#      75     layoutlmv2,
#      76     layoutlmv3,
#      77     layoutxlm,
#      78     led,
#      79     levit,
#      80     longformer,
#      81     longt5,
#      82     luke,
#      83     lxmert,
#      84     m2m_100,
#      85     marian,
#      86     maskformer,
#      87     mbart,
#      88     mbart50,
#      89     mctct,
#      90     megatron_bert,
#      91     megatron_gpt2,
#      92     mluke,
#      93     mmbt,
#      94     mobilebert,
#      95     mobilevit,
#      96     mpnet,
#      97     mt5,
#      98     mvp,
#      99     nezha,
#     100     nllb,
#     101     nystromformer,
#     102     openai,
#     103     opt,
#     104     owlvit,
#     105     pegasus,
#     106     perceiver,
#     107     phobert,
#     108     plbart,
#     109     poolformer,
#     110     prophetnet,
#     111     qdqbert,
#     112     rag,
#     113     realm,
#     114     reformer,
#     115     regnet,
#     116     rembert,
#     117     resnet,
#     118     retribert,
#     119     roberta,
#     120     roformer,
#     121     segformer,
#     122     sew,
#     123     sew_d,
#     124     speech_encoder_decoder,
#     125     speech_to_text,
#     126     speech_to_text_2,
#     127     splinter,
#     128     squeezebert,
#     129     swin,
#     130     t5,
#     131     tapas,
#     132     tapex,
#     133     trajectory_transformer,
#     134     transfo_xl,
#     135     trocr,
#     136     unispeech,
#     137     unispeech_sat,
#     138     van,
#     139     vilt,
#     140     vision_encoder_decoder,
#     141     vision_text_dual_encoder,
#     142     visual_bert,
#     143     vit,
#     144     vit_mae,
#     145     wav2vec2,
#     146     wav2vec2_conformer,
#     147     wav2vec2_phoneme,
#     148     wav2vec2_with_lm,
#     149     wavlm,
#     150     xglm,
#     151     xlm,
#     152     xlm_prophetnet,
#     153     xlm_roberta,
#     154     xlm_roberta_xl,
#     155     xlnet,
#     156     yolos,
#     157     yoso,
#     158 )
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/models/mt5/__init__.py:33
#      32 if is_sentencepiece_available():
# ---> 33     from ..t5.tokenization_t5 import T5Tokenizer
#      34 else:
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/models/t5/tokenization_t5.py:26
#      24 import sentencepiece as spm
# ---> 26 from ...tokenization_utils import PreTrainedTokenizer
#      27 from ...utils import logging
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/tokenization_utils.py:26
#      24 from typing import Any, Dict, List, Optional, Tuple, Union, overload
# ---> 26 from .tokenization_utils_base import (
#      27     ENCODE_KWARGS_DOCSTRING,
#      28     ENCODE_PLUS_ADDITIONAL_KWARGS_DOCSTRING,
#      29     INIT_TOKENIZER_DOCSTRING,
#      30     AddedToken,
#      31     BatchEncoding,
#      32     EncodedInput,
#      33     EncodedInputPair,
#      34     PreTokenizedInput,
#      35     PreTokenizedInputPair,
#      36     PreTrainedTokenizerBase,
#      37     TextInput,
#      38     TextInputPair,
#      39     TruncationStrategy,
#      40 )
#      41 from .utils import PaddingStrategy, TensorType, add_end_docstrings, logging
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:73
#      72 if is_tokenizers_available():
# ---> 73     from tokenizers import AddedToken
#      74     from tokenizers import Encoding as EncodingFast
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/tokenizers/__init__.py:79
#      76     CONTIGUOUS = "contiguous"
# ---> 79 from .tokenizers import (
#      80     Tokenizer,
#      81     Encoding,
#      82     AddedToken,
#      83     Regex,
#      84     NormalizedString,
#      85     PreTokenizedString,
#      86     Token,
#      87 )
#      88 from .tokenizers import decoders
#
# ImportError: /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/tokenizers/tokenizers.cpython-312-x86_64-linux-gnu.so: undefined symbol: PyUnicode_FromUnicode
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import pipeline
#       2 class Translator():
#       3     '''
#       4     Initializes the Hugging Face model and defines as a function
#       5     the pipeline to translate the segmented text afterwards.
#    (...)
#      10       Takes no parameters
#      11     '''
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/utils/import_utils.py:992, in _LazyModule.__getattr__(self, name)
#     990     value = self._get_module(name)
#     991 elif name in self._class_to_module.keys():
# --> 992     module = self._get_module(self._class_to_module[name])
#     993     value = getattr(module, name)
#     994 else:
#
# File /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/transformers/utils/import_utils.py:1004, in _LazyModule._get_module(self, module_name)
#    1002     return importlib.import_module("." + module_name, self.__name__)
#    1003 except Exception as e:
# -> 1004     raise RuntimeError(
#    1005         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1006         f" traceback):\n{e}"
#    1007     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv_kumo/lib/python3.12/site-packages/tokenizers/tokenizers.cpython-312-x86_64-linux-gnu.so: undefined symbol: PyUnicode_FromUnicode

# %%
trans = Translator(df_seg.head(5), df_seg_es.head(5))
# Out:
# /export/usuarios_ml4ds/ammesa/TFG-LLMs/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:367: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")

# %%
trans.split(df_seg.head(100), 'en')
trans.split(df_seg_es.head(100), 'es')

# %%
trans.translate()

# %%
trans.split_es_df
# Out:
#                 title                                            summary  \
# 0   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 1   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 2   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 3   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 4   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 5   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 6   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 7   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 8   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 9   George Washington  George Washington (Westmoreland, Virginia, Amé...
# 10  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 11  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 12  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 13  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 14  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 15  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 16  George Washington  George Washington (Westmoreland, Virginia, Amé...
#
#                                                  text lang  \
# 0   George Washington, Westmoreland, Virginia, Bri...   es
# 1   In the United States he is considered the fath...   es
# 2   Washington began winning decorations by arming...   es
# 3   The Continental Congress appointed Washington ...   es
# 4   Because of their strategy, revolutionary force...   es
# 5   In negotiations with Congress, colonial states...   es
# 6   After leading the American victory in the Inde...   es
# 7   In 1787, he presided over the Philadelphia Con...   es
# 8   He tried to create a nation capable of sustain...   es
# 9   His Proclamation of Neutrality of 1793 served ...   es
# 10  Supported plans to build a strong central gove...   es
# 11  Washington avoided war and maintained a decade...   es
# 12  Although he never officially joined the Federa...   es
# 13  His two periods of government established many...   es
# 14  Before the end of his term of government he ag...   es
# 15  Washington's Farewell Speech was an introducti...   es
# 16  He was awarded the first Congressional Gold Me...   es
#
#                                                 url  index  equivalence  \
# 0   https://en.wikipedia.org/wiki/George_Washington      0            1
# 1   https://en.wikipedia.org/wiki/George_Washington      1            1
# 2   https://en.wikipedia.org/wiki/George_Washington      2            1
# 3   https://en.wikipedia.org/wiki/George_Washington      3            1
# 4   https://en.wikipedia.org/wiki/George_Washington      4            1
# 5   https://en.wikipedia.org/wiki/George_Washington      5            1
# 6   https://en.wikipedia.org/wiki/George_Washington      6            1
# 7   https://en.wikipedia.org/wiki/George_Washington      7            1
# 8   https://en.wikipedia.org/wiki/George_Washington      8            1
# 9   https://en.wikipedia.org/wiki/George_Washington      9            1
# 10  https://en.wikipedia.org/wiki/George_Washington     10            1
# 11  https://en.wikipedia.org/wiki/George_Washington     11            1
# 12  https://en.wikipedia.org/wiki/George_Washington     12            1
# 13  https://en.wikipedia.org/wiki/George_Washington     13            1
# 14  https://en.wikipedia.org/wiki/George_Washington     14            1
# 15  https://en.wikipedia.org/wiki/George_Washington     15            1
# 16  https://en.wikipedia.org/wiki/George_Washington     16            1
#
#      id_preproc     aux_id
# 0   ES_1000_0_0  ES_1000_0
# 1   ES_1000_0_1  ES_1000_0
# 2   ES_1000_1_0  ES_1000_1
# 3   ES_1000_2_0  ES_1000_2
# 4   ES_1000_2_1  ES_1000_2
# 5   ES_1000_2_2  ES_1000_2
# 6   ES_1000_2_3  ES_1000_2
# 7   ES_1000_3_0  ES_1000_3
# 8   ES_1000_3_1  ES_1000_3
# 9   ES_1000_3_2  ES_1000_3
# 10  ES_1000_3_3  ES_1000_3
# 11  ES_1000_3_4  ES_1000_3
# 12  ES_1000_3_5  ES_1000_3
# 13  ES_1000_3_6  ES_1000_3
# 14  ES_1000_4_0  ES_1000_4
# 15  ES_1000_4_1  ES_1000_4
# 16  ES_1000_4_2  ES_1000_4

# %%
trans.trans_text_es
# Out:
# 0        George Washington (22 de febrero de 1732) [O.S
# 1     11 de febrero de 1731 – 14 de diciembre de 179...
# 2     Como comandante del Ejército Continental, Wash...
# 3     Es comúnmente conocido como el Padre de Su Paí...
# 4     Nacido en la Colonia de Virginia, Washington s...
# 5     Más tarde fue elegido para la Casa de Burgesse...
# 6     Cuando la Guerra Revolucionaria Americana cont...
# 7     Dirigió una fuerza mal organizada y equipada c...
# 8     Washington y su ejército lograron una victoria...
# 9     Washington cruzó el río Delaware y ganó las ba...
# 10    Enfrentó críticas a su mando, baja moral de tr...
# 11    En última instancia, Washington llevó a una fu...
# 12    En el Tratado de París de 1783, los británicos...
# 13    Washington fue entonces presidente de la Conve...
# 14    Washington fue elegido presidente por unanimid...
# 15                                  Como el primer U.S.
# 16    presidente, implementó un gobierno nacional fu...
# 17    Durante la Revolución Francesa, proclamó una p...
# 18    Washington sentó precedentes perdurables para ...
# 19          Presidente", y la tradición de dos períodos
# 20    Su discurso de despedida de 1796 se convirtió ...
# 21    Como plantador de tabaco y trigo en Mount Vern...
# 22    Comenzó a oponerse a la esclavitud cerca del f...
# 23    La imagen de Washington es un icono de la cult...
# 24    Tanto en las encuestas populares como en las a...
# 25    George Washington nació el 22 de febrero de 17...
# 26    Fue el primero de seis hijos de Augustine y Ma...
# 27    Su padre era un juez de paz y una prominente f...
# 28    Washington no era cercano a su padre y rara ve...
# 29    Entre sus hermanos, estaba particularmente cer...
# Name: text, dtype: object

# %%
trans.translated_df_es
# Out:
#                title                                            summary  \
# 0  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 1  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 2  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 3  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 4  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 5  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 6  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 7  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 8  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 9  George Washington  George Washington (February 22 1732 [O.S. Febr...
#
#                                                 text lang  \
# 0  George Washington (Westmoreland, Virginia, Amé...   es
# 1  Washington empezó a ganar condecoraciones arma...   es
# 2  El Congreso Continental designó a Washington c...   es
# 3  En 1787, presidió la Convención de Filadelfia ...   es
# 4  Antes de la finalización de su período de gobi...   es
# 5  George Washington (22 de febrero de 1732) [O.S...   es
# 6  Nacido en la Colonia de Virginia, Washington s...   es
# 7  Washington fue elegido presidente por unanimid...   es
# 8  La imagen de Washington es un icono de la cult...   es
# 9  George Washington nació el 22 de febrero de 17...   es
#
#                                                url       id  equivalence  \
# 0  https://en.wikipedia.org/wiki/George_Washington  63015.0            1
# 1  https://en.wikipedia.org/wiki/George_Washington  63016.0            1
# 2  https://en.wikipedia.org/wiki/George_Washington  63017.0            1
# 3  https://en.wikipedia.org/wiki/George_Washington  63018.0            1
# 4  https://en.wikipedia.org/wiki/George_Washington  63019.0            1
# 5  https://en.wikipedia.org/wiki/George_Washington      NaN            1
# 6  https://en.wikipedia.org/wiki/George_Washington      NaN            1
# 7  https://en.wikipedia.org/wiki/George_Washington      NaN            1
# 8  https://en.wikipedia.org/wiki/George_Washington      NaN            1
# 9  https://en.wikipedia.org/wiki/George_Washington      NaN            1
#
#   id_preproc  index
# 0  ES_1000_0    NaN
# 1  ES_1000_1    NaN
# 2  ES_1000_2    NaN
# 3  ES_1000_3    NaN
# 4  ES_1000_4    NaN
# 5   T_EN_0_0    0.0
# 6   T_EN_0_1    4.0
# 7   T_EN_0_2   14.0
# 8   T_EN_0_3   23.0
# 9   T_EN_0_4   25.0

# %%
trans.translated_df_en
# Out:
#                title                                            summary  \
# 0  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 1  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 2  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 3  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 4  George Washington  George Washington (February 22 1732 [O.S. Febr...
# 5  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 6  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 7  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 8  George Washington  George Washington (Westmoreland, Virginia, Amé...
# 9  George Washington  George Washington (Westmoreland, Virginia, Amé...
#
#                                                 text lang  \
# 0  George Washington (February 22 1732 [O.S. Febr...   en
# 1  Born in the Colony of Virginia, Washington bec...   en
# 2  Washington was elected president unanimously b...   en
# 3  Washington's image is an icon of American cult...   en
# 4  George Washington was born on February 22, 173...   en
# 5  George Washington, Westmoreland, Virginia, Bri...   en
# 6  Washington began winning decorations by arming...   en
# 7  The Continental Congress appointed Washington ...   en
# 8  In 1787, he presided over the Philadelphia Con...   en
# 9  Before the end of his term of government he ag...   en
#
#                                                url   id  equivalence  \
# 0  https://en.wikipedia.org/wiki/George_Washington  0.0            1
# 1  https://en.wikipedia.org/wiki/George_Washington  1.0            1
# 2  https://en.wikipedia.org/wiki/George_Washington  2.0            1
# 3  https://en.wikipedia.org/wiki/George_Washington  3.0            1
# 4  https://en.wikipedia.org/wiki/George_Washington  4.0            1
# 5  https://en.wikipedia.org/wiki/George_Washington  NaN            1
# 6  https://en.wikipedia.org/wiki/George_Washington  NaN            1
# 7  https://en.wikipedia.org/wiki/George_Washington  NaN            1
# 8  https://en.wikipedia.org/wiki/George_Washington  NaN            1
# 9  https://en.wikipedia.org/wiki/George_Washington  NaN            1
#
#     id_preproc  index
# 0       EN_0_0    NaN
# 1       EN_0_1    NaN
# 2       EN_0_2    NaN
# 3       EN_0_3    NaN
# 4       EN_0_4    NaN
# 5  T_ES_1000_0    0.0
# 6  T_ES_1000_1    2.0
# 7  T_ES_1000_2    3.0
# 8  T_ES_1000_3    7.0
# 9  T_ES_1000_4   14.0
